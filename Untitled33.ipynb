# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("derm.csv")

# %%
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
df.isnull().sum()
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# pnl_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %%
df.drop('age', axis='columns', inplace=True)

# %%
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  focal_hypergranulosis  \
# ...

# %%
X=df.iloc[:,:-1]

# %%
X
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %%
Y=df["class"]

# %%
Y
# Out:
# 0      2
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 361    4
# 362    4
# 363    3
# 364    3
# 365    1
# Name: class, Length: 366, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()
t = scaler.fit_transform(X)

# %%
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  focal_hypergranulosis  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
cls=MLPClassifier()
cls.fit(X_train,y_train)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier()

# %%
cls.score(X_test,y_test)
# Out:
# 0.972972972972973

# %%
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

# %%
pca = PCA(n_components = 4)

# %%
pc = pca.fit_transform(t)

# %%
pdf = pd.DataFrame(data = pc, columns = ["pc1", "pc2","pc3","pc4"])

# %%
pdf.head()
# Out:
#         pc1       pc2       pc3       pc4
# 0 -0.918932 -2.772265 -0.718600 -1.197310
# 1  3.164942  2.223191  0.324611 -1.415948
# 2 -5.239504  2.229374  0.275774  0.370124
# 3  4.479892  2.821623 -0.025012 -1.094104
# 4 -4.759297  2.879121  0.330586 -0.471330

# %%
result = pd.concat([pdf,Y], axis=1)

# %%
result.head()
# Out:
#         pc1       pc2       pc3       pc4  class
# 0 -0.918932 -2.772265 -0.718600 -1.197310      2
# 1  3.164942  2.223191  0.324611 -1.415948      1
# 2 -5.239504  2.229374  0.275774  0.370124      3
# 3  4.479892  2.821623 -0.025012 -1.094104      1
# 4 -4.759297  2.879121  0.330586 -0.471330      3

# %%
pca.components_
# Out:
# array([[ 0.03910644,  0.0928525 ,  0.01367695, -0.1391307 , -0.10259599,
#         -0.26034221,  0.02921953, -0.25603016,  0.21665266,  0.21438586,
#          0.11205544, -0.26220712, -0.0463071 ,  0.15755276,  0.00103462,
#         -0.22819872,  0.01334468,  0.09000067,  0.12368588,  0.24308125,
#          0.23505872,  0.23711424,  0.16037165,  0.18084491, -0.25979167,
#          0.14502221, -0.2656315 , -0.12928823, -0.26279432,  0.0154078 ,
#          0.02063409, -0.06201651, -0.26534974],
#        [ 0.11499026,  0.13772584,  0.3014567 ,  0.06225732,  0.1710753 ,
#          0.21834806, -0.14567347,  0.21016524,  0.16595973,  0.21484225,
#          0.05777136,  0.21985063, -0.0485274 ,  0.05777739, -0.15480057,
#         -0.11536389,  0.12467363,  0.02063697,  0.2121819 ,  0.24610018,
#          0.13499221,  0.24279005,  0.14997715,  0.19930623,  0.21324826,
#          0.19788909,  0.22029423, -0.17279352,  0.21369718, -0.12726182,
#         -0.13674795,  0.10694177,  0.21546351],
# ...

# %%
df_comp = pd.DataFrame(pca.components_, columns = result['class'])
  
plt.figure(figsize =(14, 6))
  
# plotting heatmap
sns.heatmap(df_comp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_37752/2813782410.py in <module>
# ----> 1 df_comp = pd.DataFrame(pca.components_, columns = result['class'])
#       2
#       3 plt.figure(figsize =(14, 6))
#       4
#       5 # plotting heatmap
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     670                 )
#     671             else:
# --> 672                 mgr = ndarray_to_mgr(
#     673                     data,
#     674                     index,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     322     )
#     323
# --> 324     _check_values_indices_shape_match(values, index, columns)
#     325
#     326     if typ == "array":
#
# ...
